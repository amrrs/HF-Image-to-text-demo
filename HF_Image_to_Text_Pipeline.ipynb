# %%
import warnings,logging
warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 4.9 MB 8.5 MB/s
#      |████████████████████████████████| 6.6 MB 18.9 MB/s
#      |████████████████████████████████| 163 kB 46.1 MB/s

# %%
from transformers import pipeline

# %% [markdown]
# # Image Captioning

# %%
caption = pipeline('image-to-text')
# Out:
# Downloading:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/982M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/211 [00:00<?, ?B/s]

# %%
# !wget -O img2text.jpg 'https://cdn.pixabay.com/photo/2022/08/17/15/13/street-7392734_960_720.jpg'

from IPython.display import Image
Image(filename='img2text.jpg')
# Out:
# --2022-09-28 20:38:10--  https://media.istockphoto.com/photos/young-satisfied-student-freelancer-woman-in-green-jacket-jeans-sit-on-picture-id1371833255?s=612x612
# Resolving media.istockphoto.com (media.istockphoto.com)... 18.65.229.49, 18.65.229.83, 18.65.229.82, ...
# Connecting to media.istockphoto.com (media.istockphoto.com)|18.65.229.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35218 (34K) [image/jpeg]
# Saving to: ‘img2text.jpg’
#
# img2text.jpg        100%[===================>]  34.39K  --.-KB/s    in 0.005s
#
# 2022-09-28 20:38:11 (6.86 MB/s) - ‘img2text.jpg’ saved [35218/35218]

# %%
caption('img2text.jpg')
# Out:
# [{'generated_text': 'a woman sitting on a bench with a laptop '}]

# %% [markdown]
# # OCR

# %%
ocr = pipeline('image-to-text', model = "microsoft/trocr-base-handwritten")
# Out:
# Downloading:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# !wget -O handwriting.jpg 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU'
# Out:
# --2022-09-28 20:17:38--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 74.125.20.113, 74.125.20.100, 74.125.20.138, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|74.125.20.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4324 (4.2K) [image/jpeg]
# Saving to: ‘handwriting.jpg’
#
# handwriting.jpg     100%[===================>]   4.22K  --.-KB/s    in 0s
#
# 2022-09-28 20:17:38 (32.5 MB/s) - ‘handwriting.jpg’ saved [4324/4324]

# %%
from IPython.display import Image
Image(filename='handwriting.jpg')

# %%
ocr('handwriting.jpg')
# Out:
# [{'generated_text': 'Hope you have done it.'}]
